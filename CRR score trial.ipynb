# %%
import numpy as np
import pandas as pd
import sklearn as sk
import random
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Read the data into dataframe
CRR = pd.read_csv('OBU_fakedata.csv')
CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                       NaN     v   NaN   NaN   NaN   NaN     v  ...
# 3                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y     v     v   NaN   NaN   NaN   NaN  ...
# 80130                     Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_PURPOSE CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP  \
# 0                   D                NaN                NaN       1Z    0.0
# 1                 NaN                NaN                NaN       1Z    0.0
# 2                   5                NaN                NaN       1Z    0.0
# 3                   E                NaN                NaN       1Z    0.0
# 4                   E                NaN                NaN       1Z    0.0
# ...               ...                ...                ...      ...    ...
# 80127               E                NaN                NaN       1Z    0.0
# 80128               1                NaN                NaN       1Z    2.0
# 80129             NaN                NaN                NaN       5Z    0.0
# 80130             NaN                NaN                NaN       1Z    0.0
# 80131             NaN                NaN                NaN       1Z    1.0
#
#       CONFIRM_TYPE CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT
# 0              1.0         Z             0.0                     NaN         N
# 1              1.0         Z             0.0                     NaN         N
# 2              1.0         Z             0.0                     NaN         N
# 3              1.0         Z             0.0                     NaN         N
# 4              1.0       NaN             0.0                     NaN         N
# ...            ...       ...             ...                     ...       ...
# 80127          3.0         Z             NaN                     NaN         N
# 80128          NaN       NaN             0.0                     NaN         N
# 80129          1.0       NaN             NaN                     NaN         N
# 80130          NaN         Z             0.0                     NaN         N
# 80131          1.0         Z             0.0                     NaN         N
#
# [80132 rows x 63 columns]

# %%
# Set a column to calculate the score
CRR['SCORE'] = 0
CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                       NaN     v   NaN   NaN   NaN   NaN     v  ...
# 3                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y     v     v   NaN   NaN   NaN   NaN  ...
# 80130                     Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    0.0          1.0
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          1.0
# 3                    NaN                NaN       1Z    0.0          1.0
# 4                    NaN                NaN       1Z    0.0          1.0
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    0.0          3.0
# 80128                NaN                NaN       1Z    2.0          NaN
# 80129                NaN                NaN       5Z    0.0          1.0
# 80130                NaN                NaN       1Z    0.0          NaN
# 80131                NaN                NaN       1Z    1.0          1.0
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE
# 0             Z             0.0                     NaN         N     0
# 1             Z             0.0                     NaN         N     0
# 2             Z             0.0                     NaN         N     0
# 3             Z             0.0                     NaN         N     0
# 4           NaN             0.0                     NaN         N     0
# ...         ...             ...                     ...       ...   ...
# 80127         Z             NaN                     NaN         N     0
# 80128       NaN             0.0                     NaN         N     0
# 80129       NaN             NaN                     NaN         N     0
# 80130         Z             0.0                     NaN         N     0
# 80131         Z             0.0                     NaN         N     0
#
# [80132 rows x 64 columns]

# %%
# First trial: Calculating the score according to the client's risk score document
CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*100
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*100
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*100

CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += 100
CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += 100
CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += 100
CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += 100
CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += 50
CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += 1
CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += 1
CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += 100
CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += 1
CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += 100
CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += 1
CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += 100
CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += 50
CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += 1
CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += 100

#CRR.loc[CRR['RISK_LEVEL'] == 'H', 'SCORE'] += 100
#CRR.loc[CRR['RISK_LEVEL'] == 'M', 'SCORE'] += 50
#CRR.loc[CRR['RISK_LEVEL'] == 'L', 'SCORE'] += 1

CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                       NaN     v   NaN   NaN   NaN   NaN     v  ...
# 3                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y     v     v   NaN   NaN   NaN   NaN  ...
# 80130                     Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    0.0          1.0
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          1.0
# 3                    NaN                NaN       1Z    0.0          1.0
# 4                    NaN                NaN       1Z    0.0          1.0
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    0.0          3.0
# 80128                NaN                NaN       1Z    2.0          NaN
# 80129                NaN                NaN       5Z    0.0          1.0
# 80130                NaN                NaN       1Z    0.0          NaN
# 80131                NaN                NaN       1Z    1.0          1.0
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE
# 0             Z             0.0                     NaN         N   150
# 1             Z             0.0                     NaN         N   101
# 2             Z             0.0                     NaN         N   350
# 3             Z             0.0                     NaN         N   300
# 4           NaN             0.0                     NaN         N   250
# ...         ...             ...                     ...       ...   ...
# 80127         Z             NaN                     NaN         N   200
# 80128       NaN             0.0                     NaN         N   300
# 80129       NaN             NaN                     NaN         N   401
# 80130         Z             0.0                     NaN         N   300
# 80131         Z             0.0                     NaN         N   300
#
# [80132 rows x 64 columns]

# %%
# Sort by the score
CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                NaN
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                NaN
# 80131                Y                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 3                         Y     v   NaN     v   NaN   NaN   NaN  ...
# 4                         Y     v     v     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80128                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80130                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80131                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    0.0          NaN
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          NaN
# 3                    NaN                NaN       1Z    0.0          3.0
# 4                    NaN                NaN       1Z    0.0          NaN
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    0.0          1.0
# 80128                NaN                NaN       1Z    0.0          NaN
# 80129                NaN                NaN       1Z    0.0          NaN
# 80130                NaN                NaN       5Z    0.0          NaN
# 80131                NaN                NaN       1Z    0.0          NaN
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE
# 0             Z             NaN                     NaN         N   900
# 1             Z             NaN                     NaN         N   900
# 2             Z             0.0                     NaN         N   900
# 3           NaN             NaN                     NaN         N   900
# 4             Z             0.0                     NaN         N   801
# ...         ...             ...                     ...       ...   ...
# 80127       NaN             0.0                     NaN         N     1
# 80128         Z             NaN                     NaN         N     1
# 80129         Z             0.0                     NaN         N     1
# 80130       NaN             0.0                     NaN         N     1
# 80131         Z             0.0                     NaN         N     1
#
# [80132 rows x 64 columns]

# %%
# Check how many Y is 'True'
len(CRR[CRR['SAR_ALERT']=='Y'])
# Out:
# 1691

# %%
# Create a column to save the outcome of prediction
CRR['PREDICT'] = 'N'

# %%
# Set data with top Nth score as doubtful
CRR.loc[range(0,len(CRR[CRR['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'
CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                NaN
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                NaN
# 80131                Y                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 3                         Y     v   NaN     v   NaN   NaN   NaN  ...
# 4                         Y     v     v     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80128                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80130                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 80131                     Y   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE CORP_TYPE  \
# 0                    NaN       1Z    0.0          NaN         Z
# 1                    NaN       1Z    0.0          1.0         Z
# 2                    NaN       1Z    0.0          NaN         Z
# 3                    NaN       1Z    0.0          3.0       NaN
# 4                    NaN       1Z    0.0          NaN         Z
# ...                  ...      ...    ...          ...       ...
# 80127                NaN       1Z    0.0          1.0       NaN
# 80128                NaN       1Z    0.0          NaN         Z
# 80129                NaN       1Z    0.0          NaN         Z
# 80130                NaN       5Z    0.0          NaN       NaN
# 80131                NaN       1Z    0.0          NaN         Z
#
#       CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE PREDICT
# 0                 NaN                     NaN         N   900       Y
# 1                 NaN                     NaN         N   900       Y
# 2                 0.0                     NaN         N   900       Y
# 3                 NaN                     NaN         N   900       Y
# 4                 0.0                     NaN         N   801       Y
# ...               ...                     ...       ...   ...     ...
# 80127             0.0                     NaN         N     1       N
# 80128             NaN                     NaN         N     1       N
# 80129             0.0                     NaN         N     1       N
# 80130             0.0                     NaN         N     1       N
# 80131             0.0                     NaN         N     1       N
#
# [80132 rows x 65 columns]

# %%
# Check the quality of the model
TT_PT = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')])
TT_PT
# Out:
# 67

# %%
TT_PF = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='N')])
TT_PF
# Out:
# 1624

# %%
TF_PF = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')])
TF_PF
# Out:
# 76817

# %%
TF_PT = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='Y')])
TF_PT
# Out:
# 1624

# %%
accuracy = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]) + len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')]))/len(CRR) 
print('accuracy: ', accuracy)
# Out:
# accuracy:  0.9594668796485798

# %%
recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
print('recall: ', recall)
# Out:
# recall:  0.039621525724423415

# %%
precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
print('precision: ', precision)
# Out:
# precision:  0.039621525724423415

# %%
# Second trial: 迎合模擬資料
df = pd.read_csv('OBU_fakedata.csv')
df['SCORE'] = 0
df
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                       NaN     v   NaN   NaN   NaN   NaN     v  ...
# 3                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y     v     v   NaN   NaN   NaN   NaN  ...
# 80130                     Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    0.0          1.0
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          1.0
# 3                    NaN                NaN       1Z    0.0          1.0
# 4                    NaN                NaN       1Z    0.0          1.0
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    0.0          3.0
# 80128                NaN                NaN       1Z    2.0          NaN
# 80129                NaN                NaN       5Z    0.0          1.0
# 80130                NaN                NaN       1Z    0.0          NaN
# 80131                NaN                NaN       1Z    1.0          1.0
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE
# 0             Z             0.0                     NaN         N     0
# 1             Z             0.0                     NaN         N     0
# 2             Z             0.0                     NaN         N     0
# 3             Z             0.0                     NaN         N     0
# 4           NaN             0.0                     NaN         N     0
# ...         ...             ...                     ...       ...   ...
# 80127         Z             NaN                     NaN         N     0
# 80128       NaN             0.0                     NaN         N     0
# 80129       NaN             NaN                     NaN         N     0
# 80130         Z             0.0                     NaN         N     0
# 80131         Z             0.0                     NaN         N     0
#
# [80132 rows x 64 columns]

# %%
df.loc[df['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += 100
df.loc[df['EB_FG'] == 'v', 'SCORE'] += 100
df.loc[df['CDD_STATUS'] == 'N', 'SCORE'] += 100
df['AMT_RANGE'] = df['AMT_RANGE'].fillna(0)
df['SCORE'] = df['SCORE'] + df['AMT_RANGE']*100
df['OBU_ANNUAL_INCOME'] = df['OBU_ANNUAL_INCOME'].fillna(0)
df['SCORE'] = df['SCORE'] + df['OBU_ANNUAL_INCOME']*100
df = df.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
df
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                  NaN                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN     v   NaN   NaN   NaN  ...
# 2                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 3                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN     v   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80130                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v     v   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    1.0          1.0
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          1.0
# 3                    NaN                NaN       1Z    0.0          NaN
# 4                    NaN                NaN       1Z    0.0          NaN
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    1.0          NaN
# 80128                NaN                NaN       5Z    0.0          1.0
# 80129                NaN                NaN       1Z    NaN          1.0
# 80130                NaN                NaN       1Z    0.0          NaN
# 80131                NaN                NaN       1Z    1.0          NaN
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT  SCORE
# 0             Z             0.0                     NaN         Y  900.0
# 1             Z             0.0                     NaN         Y  900.0
# 2           NaN             0.0                     NaN         Y  900.0
# 3             Z             0.0                     NaN         Y  900.0
# 4             4             0.0                     NaN         Y  900.0
# ...         ...             ...                     ...       ...    ...
# 80127         Z             0.0                     NaN         N    0.0
# 80128         Z             0.0                     NaN         N    0.0
# 80129       NaN             NaN                     NaN         N    0.0
# 80130       NaN             0.0                     NaN         N    0.0
# 80131         4             NaN                     NaN         N    0.0
#
# [80132 rows x 64 columns]

# %%
df['PREDICT'] = 'N'
df.loc[range(0,len(df[df['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'
df
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                  NaN                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN     v   NaN   NaN   NaN  ...
# 2                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 3                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN     v   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80130                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v     v   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE CORP_TYPE  \
# 0                    NaN       1Z    1.0          1.0         Z
# 1                    NaN       1Z    0.0          1.0         Z
# 2                    NaN       1Z    0.0          1.0       NaN
# 3                    NaN       1Z    0.0          NaN         Z
# 4                    NaN       1Z    0.0          NaN         4
# ...                  ...      ...    ...          ...       ...
# 80127                NaN       1Z    1.0          NaN         Z
# 80128                NaN       5Z    0.0          1.0         Z
# 80129                NaN       1Z    NaN          1.0       NaN
# 80130                NaN       1Z    0.0          NaN       NaN
# 80131                NaN       1Z    1.0          NaN         4
#
#       CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT  SCORE PREDICT
# 0                 0.0                     NaN         Y  900.0       Y
# 1                 0.0                     NaN         Y  900.0       Y
# 2                 0.0                     NaN         Y  900.0       Y
# 3                 0.0                     NaN         Y  900.0       Y
# 4                 0.0                     NaN         Y  900.0       Y
# ...               ...                     ...       ...    ...     ...
# 80127             0.0                     NaN         N    0.0       N
# 80128             0.0                     NaN         N    0.0       N
# 80129             NaN                     NaN         N    0.0       N
# 80130             0.0                     NaN         N    0.0       N
# 80131             NaN                     NaN         N    0.0       N
#
# [80132 rows x 65 columns]

# %%
accuracy = (len(df[(df['SAR_ALERT']=='Y') & (df['PREDICT']=='Y')]) + len(df[(df['SAR_ALERT']=='N') & (df['PREDICT']=='N')]))/len(df) 
print('accuracy: ', accuracy)
# Out:
# accuracy:  1.0

# %%
recall = (len(df[(df['SAR_ALERT']=='Y') & (df['PREDICT']=='Y')]))/len(df[df['SAR_ALERT']=='Y'])
print('recall: ', recall)
# Out:
# recall:  1.0

# %%
precision = (len(df[(df['SAR_ALERT']=='Y') & (df['PREDICT']=='Y')]))/len(df[df['PREDICT']=='Y'])
print('precision: ', precision)
# Out:
# precision:  1.0

# %%
df['TARGET'] = (df['CMFCUS1_FINANCIAL_ACT'] == 'Y').astype(int) + (df['EB_FG'] == 'v').astype(int) + (df['CDD_STATUS'] == 'N').astype(int) + (df['AMT_RANGE'].replace('NA', 0)).astype(int) + (df['OBU_ANNUAL_INCOME'].replace('NA', 0)).astype(int)
df.loc[df.TARGET>=7]
# Out:
#      CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                   N                     Y                  N
# 1                   N                     Y                  N
# 2                   N                     Y                  N
# 3                   N                     Y                  N
# 4                 NaN                     Y                  N
# ...               ...                   ...                ...
# 1686                N                     Y                  N
# 1687                N                     Y                  N
# 1688                N                     Y                  N
# 1689                N                     Y                  N
# 1690                N                     Y                  N
#
#      CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ... CUST_TYP  \
# 0                        Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 1                        Y     v   NaN     v   NaN   NaN   NaN  ...       1Z
# 2                        Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 3                        Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 4                        Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# ...                    ...   ...   ...   ...   ...   ...   ...  ...      ...
# 1686                     Y     v   NaN   NaN   NaN   NaN   NaN  ...       5Z
# 1687                     Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 1688                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 1689                     Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
# 1690                     Y     v   NaN   NaN   NaN   NaN   NaN  ...       1Z
#
#      LN_TYP CONFIRM_TYPE CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG  \
# 0       1.0          1.0         Z             0.0                     NaN
# 1       0.0          1.0         Z             0.0                     NaN
# 2       0.0          1.0       NaN             0.0                     NaN
# 3       0.0          NaN         Z             0.0                     NaN
# 4       0.0          NaN         4             0.0                     NaN
# ...     ...          ...       ...             ...                     ...
# 1686    0.0          1.0         Z             0.0                     NaN
# 1687    1.0          1.0         Z             NaN                     NaN
# 1688    0.0          NaN         Z             NaN                     NaN
# 1689    0.0          1.0       NaN             NaN                     NaN
# 1690    0.0          NaN         Z             NaN                     NaN
#
#      SAR_ALERT  SCORE PREDICT TARGET
# 0            Y  900.0       Y      9
# 1            Y  900.0       Y      9
# 2            Y  900.0       Y      9
# 3            Y  900.0       Y      9
# 4            Y  900.0       Y      9
# ...        ...    ...     ...    ...
# 1686         Y  700.0       Y      7
# 1687         Y  700.0       Y      7
# 1688         Y  700.0       Y      7
# 1689         Y  700.0       Y      7
# 1690         Y  700.0       Y      7
#
# [1691 rows x 66 columns]

# %%
df.to_csv('df.csv')

# %%
# Third trial: Randomly assign weights for those variables included in the client's risk assessment document
## 正式開始，讀取乾淨資料，加入分數欄位
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0
CRR
# Out:
#       CMFCUS1_VIP_CODE CMFCUS1_BUSINESS_FLAG CMFCUS1_NOTAX_FLAG  \
# 0                    N                     Y                  N
# 1                    N                     Y                  N
# 2                    N                     Y                  N
# 3                    N                     Y                  N
# 4                    N                     Y                  N
# ...                ...                   ...                ...
# 80127                N                     Y                  N
# 80128                N                     Y                  N
# 80129                N                     Y                  N
# 80130                N                     Y                  N
# 80131                N                     Y                  N
#
#       CMFCUS1_FINANCIAL_ACT DP_FG LN_FG IX_FG BD_FG FD_FG WM_FG  ...  \
# 0                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 1                         Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 2                       NaN     v   NaN   NaN   NaN   NaN     v  ...
# 3                       NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 4                         Y     v   NaN     v   NaN   NaN   NaN  ...
# ...                     ...   ...   ...   ...   ...   ...   ...  ...
# 80127                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80128                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
# 80129                     Y     v     v   NaN   NaN   NaN   NaN  ...
# 80130                     Y     v   NaN   NaN   NaN   NaN   NaN  ...
# 80131                   NaN     v   NaN   NaN   NaN   NaN   NaN  ...
#
#       CMFCUS1_DERIVATIVE CMFCUS1_TITLE_CODE CUST_TYP LN_TYP CONFIRM_TYPE  \
# 0                    NaN                NaN       1Z    0.0          1.0
# 1                    NaN                NaN       1Z    0.0          1.0
# 2                    NaN                NaN       1Z    0.0          1.0
# 3                    NaN                NaN       1Z    0.0          1.0
# 4                    NaN                NaN       1Z    0.0          1.0
# ...                  ...                ...      ...    ...          ...
# 80127                NaN                NaN       1Z    0.0          3.0
# 80128                NaN                NaN       1Z    2.0          NaN
# 80129                NaN                NaN       5Z    0.0          1.0
# 80130                NaN                NaN       1Z    0.0          NaN
# 80131                NaN                NaN       1Z    1.0          1.0
#
#       CORP_TYPE CMFCUS25_BRANCH CMFCUS25_FORE_CASH_FLAG SAR_ALERT SCORE
# 0             Z             0.0                     NaN         N     0
# 1             Z             0.0                     NaN         N     0
# 2             Z             0.0                     NaN         N     0
# 3             Z             0.0                     NaN         N     0
# 4           NaN             0.0                     NaN         N     0
# ...         ...             ...                     ...       ...   ...
# 80127         Z             NaN                     NaN         N     0
# 80128       NaN             0.0                     NaN         N     0
# 80129       NaN             NaN                     NaN         N     0
# 80130         Z             0.0                     NaN         N     0
# 80131         Z             0.0                     NaN         N     0
#
# [80132 rows x 64 columns]

# %%
# 生成一與變數相等長度之字典，給予各變數一對應隨機值
# Create a dictionary having specific numbers of keys pair with random values
def RandDict(n):
    for i in range(n):
        values = [random.random() for i in range(n)]
        keys = ['key_' + str(i) for i in range(n)]
        dictionary = dict(zip(keys, values))
    return dictionary

# %%
# Test the function
Dict = RandDict(5)
Dict
# Out:
# {'key_0': 0.8446972581384187,
#  'key_1': 0.6852340920127241,
#  'key_2': 0.6363334614231524,
#  'key_3': 0.023862756742985658,
#  'key_4': 0.4089259365078458}

# %%
Dict['key_0']
# Out:
# 0.8446972581384187

# %%
# Create a blank list to restore outcomes(F1-score, weights of the slope)
# 生成空串列以儲存結果
outcome = []
beta = [None] * 1000
# 模擬 N 次
for i in range(1000):
    Dict = RandDict(18)
    CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_0']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_1']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_2']

    CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_3']
    CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_4']
    CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_5']
    CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_6']
    CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_7']
    CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_8']
    CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_9']
    CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_10']
    CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_11']
    CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_12']
    CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_13']
    CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_14']
    CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_15']
    CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_16']
    CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_17']

    # 分數排序，取與真實 Y 相等數量之預測 Y
    CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
    CRR['PREDICT'] = 'N'
    CRR.loc[range(0,len(CRR[CRR['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'

    # 結果預測成效
    recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
    precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
    f1_score = 2*precision*recall/(precision+recall)

    # 儲存結果
    outcome.append(f1_score)
    beta[i] = Dict.values()

# %%
outcome
# Out:
# [0.0319337670017741,
#  0.039621525724423415,
#  0.0319337670017741,
#  0.03075103489059728,
#  0.03252513305736251,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03666469544648137,
#  0.03666469544648137,
#  0.03429923122412774,
#  0.03429923122412774,
#  0.03725606150206978,
#  0.036073329390892965,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03489059727971614,
#  0.03252513305736251,
#  0.03311649911295092,
#  0.03311649911295092,
#  0.033707865168539325,
#  0.03429923122412774,
#  0.03429923122412774,
#  0.03548196333530455,
#  0.03489059727971614,
#  0.036073329390892965,
#  0.036073329390892965,
#  0.033707865168539325,
#  0.03548196333530455,
#  0.03311649911295092,
#  0.03429923122412774,
#  0.03311649911295092,
#  0.03489059727971614,
#  0.03429923122412774,
#  0.03548196333530455,
#  0.03489059727971614,
#  0.033707865168539325,
#  0.03489059727971614,
#  0.03311649911295092,
#  0.03548196333530455,
#  0.03311649911295092,
#  0.03489059727971614,
#  0.033707865168539325,
#  0.03489059727971614,
#  0.03311649911295092,
#  0.03489059727971614,
#  0.03311649911295092,
#  0.03429923122412774,
#  0.03311649911295092,
#  0.03489059727971614,
#  0.03311649911295092,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04139562389118864,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04080425783560024,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04080425783560024,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04080425783560024,
#  0.03903015966883501,
#  0.04080425783560024,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.03903015966883501,
#  0.04080425783560024,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04080425783560024,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.039621525724423415,
#  0.04080425783560024,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04080425783560024,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.03784742755765819,
#  0.04021289178001183,
#  0.03784742755765819,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.04021289178001183,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.04021289178001183,
#  0.0384387936132466,
#  0.04021289178001183,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.039621525724423415,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.036073329390892965,
#  0.03725606150206978,
#  0.036073329390892965,
#  0.03666469544648137,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03666469544648137,
#  0.036073329390892965,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.036073329390892965,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.036073329390892965,
#  0.0384387936132466,
#  0.036073329390892965,
#  0.03784742755765819,
#  0.036073329390892965,
#  0.03784742755765819,
#  0.036073329390892965,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03725606150206978,
#  0.03548196333530455,
#  0.03548196333530455,
#  0.03489059727971614,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03548196333530455,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.039621525724423415,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.036073329390892965,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.03903015966883501,
#  0.03666469544648137,
#  0.03903015966883501,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.036073329390892965,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03548196333530455,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.03784742755765819,
#  0.03903015966883501,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.03725606150206978,
#  0.0384387936132466,
#  0.03725606150206978,
#  0.03903015966883501,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03784742755765819,
#  0.0384387936132466,
#  0.0384387936132466,
#  0.03784742755765819,
#  0.036073329390892965,
#  0.03666469544648137,
#  0.03725606150206978,
#  0.03784742755765819,
#  0.03666469544648137,
#  0.03666469544648137,
#  0.036073329390892965,
#  0.03548196333530455,
#  0.03725606150206978,
#  0.03311649911295092]

# %%
# The distribution of outcomes
# 結果分配
plt.hist(outcome)
# Out:
# (array([  1.,   4.,  15.,  17.,   9.,  65., 321., 406., 147.,  15.]),
#  array([0.03075103, 0.03181549, 0.03287995, 0.03394441, 0.03500887,
#         0.03607333, 0.03713779, 0.03820225, 0.03926671, 0.04033116,
#         0.04139562]),
#  <BarContainer object of 10 artists>)

# %%
# The best outcome
# 最佳結果
max(outcome)
# Out:
# 0.04139562389118864

# %%
# Find where is the best outcome
outcome.index(max(outcome))
# Out:
# 78

# %%
# Call the weights of the best outcome, and it would be an useful anchor for our model
# 最佳結果係數
beta[outcome.index(max(outcome))]
# Out:
# dict_values([0.6672174968986446, 0.1722351182626527, 0.7614694318164287, 0.2733380095626765, 0.9877499693075573, 0.3040033048489683, 0.6847689394318155, 0.4045872298669758, 0.3293836689186792, 0.24753520556255582, 0.44762956222794725, 0.17075157454651835, 0.3973274368828207, 0.8710149410238065, 0.342097119313862, 0.0017788585332431106, 0.34843741065649947, 0.7451495144645264])

# %%
## 4th Trial: Adjust the method, predicting top 5% as doubtful but not as same as the numbers of true Y
## 換假設
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

def RandDict(n):
    for i in range(n):
        values = [random.random() for i in range(n)]
        keys = ['key_' + str(i) for i in range(n)]
        dictionary = dict(zip(keys, values))
    return dictionary

outcome = []
beta = [None] * 1000

for i in range(1000):
    Dict = RandDict(18)
    CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_0']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_1']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_2']

    CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_3']
    CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_4']
    CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_5']
    CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_6']
    CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_7']
    CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_8']
    CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_9']
    CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_10']
    CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_11']
    CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_12']
    CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_13']
    CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_14']
    CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_15']
    CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_16']
    CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_17']
    
    # 分數排序，取前 5% 分數者作為預測 Y
    CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
    CRR['PREDICT'] = 'N'
    CRR.loc[range(0,round(len(CRR)*0.5)),'PREDICT'] = 'Y'
    
    recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
    precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
    f1_score = 2*precision*recall/(precision+recall)
    
    outcome.append(f1_score)
    beta[i] = Dict.values()

# %%
plt.hist(outcome)
# Out:
# (array([ 76., 111., 332., 204., 207.,  58.,   7.,   2.,   1.,   2.]),
#  array([0.04942884, 0.05090883, 0.05238882, 0.05386881, 0.0553488 ,
#         0.0568288 , 0.05830879, 0.05978878, 0.06126877, 0.06274876,
#         0.06422875]),
#  <BarContainer object of 10 artists>)

# %%
max(outcome)
# Out:
# 0.06422875206552196

# %%
beta[outcome.index(max(outcome))]
# Out:
# dict_values([0.8068848151667771, 0.8108491991664847, 0.8685550798195886, 0.48936505863355706, 0.9105939409818165, 0.8232693924027246, 0.2662698458424715, 0.9537777664182376, 0.09059109181034286, 0.45925288578306933, 0.21475544186065432, 0.06378746236280353, 0.822380917396798, 0.9496471788566562, 0.03338042669661234, 0.09587965291042588, 0.5048934859236228, 0.9903457330375268])

# %%
# Feed the best outcome into the model and check the quality of prediction for it
# 代入最佳結果
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

values = beta[outcome.index(max(outcome))]
keys = ['key_' + str(i) for i in range(18)]
Dict = dict(zip(keys, values))

CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_0']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_1']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_2']

CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_3']
CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_4']
CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_5']
CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_6']
CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_7']
CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_8']
CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_9']
CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_10']
CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_11']
CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_12']
CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_13']
CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_14']
CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_15']
CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_16']
CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_17']

CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
CRR['PREDICT'] = 'N'
CRR.loc[range(0,round(len(CRR)*0.05)),'PREDICT'] = 'Y'

accuracy = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]) + len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')]))/len(CRR) 
recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
f1_score = 2*precision*recall/(precision+recall)
TT_PT = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')])
TT_PF = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='N')])
TF_PF = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')])
TF_PT = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='Y')])

# %%
print('Accuracy: ', accuracy, 'f1: ', f1_score, 'TT_PT: ', TT_PT, 'TT_PF: ', TT_PF, 'TF_PF: ', TF_PF, 'TF_PT: ', TF_PT)
# Out:
# Accuracy:  0.9323366445365148 f1:  0.04843804843804844 TT_PT:  138 TT_PF:  1553 TF_PF:  74572 TF_PT:  3869

# %%
print(recall, precision)
# Out:
# 0.08160851567120048 0.03443973047167457

# %%
## 5th Trial: Applying the randomly-weights-assigning method to those variables the simulated data really including
## 換變數去迎合模擬資料
df = pd.read_csv('OBU_fakedata.csv')
df['SCORE'] = 0

def RandDict(n):
    for i in range(n):
        values = [random.random() for i in range(n)]
        keys = ['key_' + str(i) for i in range(n)]
        dictionary = dict(zip(keys, values))
    return dictionary

outcome = []
beta = [None] * 100

for i in range(100):
    Dict = RandDict(5)
    df.loc[df['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += Dict['key_0']
    df.loc[df['EB_FG'] == 'v', 'SCORE'] += Dict['key_1']
    df.loc[df['CDD_STATUS'] == 'N', 'SCORE'] += Dict['key_2']
    df['AMT_RANGE'] = df['AMT_RANGE'].fillna(0)
    df['SCORE'] = df['SCORE'] + df['AMT_RANGE']*Dict['key_3']
    df['OBU_ANNUAL_INCOME'] = df['OBU_ANNUAL_INCOME'].fillna(0)
    df['SCORE'] = df['SCORE'] + df['OBU_ANNUAL_INCOME']*Dict['key_4']

    
    # 分數排序，取真實 Y數量生成預測 Y
    df = df.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
    df['PREDICT'] = 'N'
    df.loc[range(0,len(df[df['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'
    
    recall = (len(df[(df['SAR_ALERT']=='Y') & (df['PREDICT']=='Y')]))/len(df[df['SAR_ALERT']=='Y'])
    precision = (len(df[(df['SAR_ALERT']=='Y') & (df['PREDICT']=='Y')]))/len(df[df['PREDICT']=='Y'])
    f1_score = 2*precision*recall/(precision+recall)
    
    outcome.append(f1_score)
    beta[i] = Dict.values()

# %%
plt.hist(outcome)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  1., 97.]),
#  array([0.66765228, 0.70088705, 0.73412182, 0.76735659, 0.80059137,
#         0.83382614, 0.86706091, 0.90029568, 0.93353046, 0.96676523,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
max(outcome)
# Out:
# 1.0

# %%
beta[outcome.index(max(outcome))]
# Out:
# dict_values([0.9419838434727796, 0.8848937509964383, 0.5134656920956769, 0.9573094144616435, 0.4522601194750723])

# %%
## 6th Trial: Applying the randomly-weights-assigning method to all variables included above
## 換變數，包含模擬資料實際使用變數 & 客戶風險評估文件變數
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

def RandDict(n):
    for i in range(n):
        values = [random.random() for i in range(n)]
        keys = ['key_' + str(i) for i in range(n)]
        dictionary = dict(zip(keys, values))
    return dictionary

outcome = []
beta = [None] * 1000

for i in range(1000):
    Dict = RandDict(22)
    CRR.loc[CRR['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += Dict['key_0']
    CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_1']
    CRR.loc[CRR['CDD_STATUS'] == 'N', 'SCORE'] += Dict['key_2']
    CRR['AMT_RANGE'] = CRR['AMT_RANGE'].fillna(0)
    CRR['SCORE'] = CRR['SCORE'] + CRR['AMT_RANGE']*Dict['key_3']
    CRR['OBU_ANNUAL_INCOME'] = CRR['OBU_ANNUAL_INCOME'].fillna(0)
    CRR['SCORE'] = CRR['SCORE'] + CRR['OBU_ANNUAL_INCOME']*Dict['key_4']
    
    CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_5']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_6']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_7']

    CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_8']
    CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_9']
    CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_10']
    CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_11']
    CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_12']
    CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_13']
    CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_14']
    CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_15']
    CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_16']
    CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_17']
    CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_18']
    CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_19']
    CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_20']
    CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_21']
    
    # 分數排序，取前5%高分者生成預測 Y
    CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
    CRR['PREDICT'] = 'N'
    CRR.loc[range(0,round(len(CRR)*0.05)),'PREDICT'] = 'Y'
    
    recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
    precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
    f1_score = 2*precision*recall/(precision+recall)
    
    outcome.append(f1_score)
    beta[i] = Dict.values()

# %%
plt.hist(outcome)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   0.,   1.,   4.,   3., 990.]),
#  array([0.43839944, 0.45307125, 0.46774307, 0.48241488, 0.4970867 ,
#         0.51175851, 0.52643033, 0.54110214, 0.55577396, 0.57044577,
#         0.58511759]),
#  <BarContainer object of 10 artists>)

# %%
max(outcome)
# Out:
# 0.585117585117585

# %%
beta[outcome.index(max(outcome))]
# Out:
# dict_values([0.2959257672885298, 0.5604611302847669, 0.47085852300966324, 0.5048735854255124, 0.8524542696056324, 0.8522395879751657, 0.9484997390863298, 0.6788759226629167, 0.530572906240599, 0.23326759470798708, 0.6412245263338563, 0.12736383059714684, 0.13176761075167565, 0.21181249812281822, 0.09856593306400274, 0.13072024160703277, 0.4495865624766675, 0.09073750835349403, 0.9397707203955302, 0.1996795693155482, 0.7188102424355856, 0.8530219376686007])

# %%
# Feed the best outcome into the model and check the quality of prediction for it
# 代入最佳結果
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

values = beta[outcome.index(max(outcome))]
keys = ['key_' + str(i) for i in range(22)]
Dict = dict(zip(keys, values))

CRR.loc[CRR['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += Dict['key_0']
CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_1']
CRR.loc[CRR['CDD_STATUS'] == 'N', 'SCORE'] += Dict['key_2']
CRR['AMT_RANGE'] = CRR['AMT_RANGE'].fillna(0)
CRR['SCORE'] = CRR['SCORE'] + CRR['AMT_RANGE']*Dict['key_3']
CRR['OBU_ANNUAL_INCOME'] = CRR['OBU_ANNUAL_INCOME'].fillna(0)
CRR['SCORE'] = CRR['SCORE'] + CRR['OBU_ANNUAL_INCOME']*Dict['key_4']
    
CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_5']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_6']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_7']

CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_8']
CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_9']
CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_10']
CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_11']
CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_12']
CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_13']
CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_14']
CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_15']
CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_16']
CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_17']
CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_18']
CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_19']
CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_20']
CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_21']

CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
CRR['PREDICT'] = 'N'
CRR.loc[range(0,round(len(CRR)*0.05)),'PREDICT'] = 'Y'

accuracy = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]) + len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')]))/len(CRR) 
recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
f1_score = 2*precision*recall/(precision+recall)
TT_PT = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')])
TT_PF = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='N')])
TF_PF = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')])
TF_PT = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='Y')])

# %%
## F1 score 不同最佳結果，需要 Debug
print('Accuracy: ', accuracy, 'f1: ', f1_score, 'TT_PT: ', TT_PT, 'TT_PF: ', TT_PF, 'TF_PF: ', TF_PF, 'TF_PT: ', TF_PT)
# Out:
# Accuracy:  0.9688014775620226 f1:  0.5612495612495613 TT_PT:  1599 TT_PF:  92 TF_PF:  76033 TF_PT:  2408

# %%
print(recall, precision)
# Out:
# 0.9455943228858663 0.3990516595957075

# %%
## 6th Trial version 2: Applying the randomly-weights-assigning method to all variables included above
## 換變數，包含模擬資料實際使用變數 & 客戶風險評估文件變數
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

def RandDict(n):
    for i in range(n):
        values = [random.random() for i in range(n)]
        keys = ['key_' + str(i) for i in range(n)]
        dictionary = dict(zip(keys, values))
    return dictionary

outcome = []
beta = [None] * 1000

for i in range(1000):
    Dict = RandDict(22)
    CRR.loc[CRR['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += Dict['key_0']
    CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_1']
    CRR.loc[CRR['CDD_STATUS'] == 'N', 'SCORE'] += Dict['key_2']
    CRR['AMT_RANGE'] = CRR['AMT_RANGE'].fillna(0)
    CRR['SCORE'] = CRR['SCORE'] + CRR['AMT_RANGE']*Dict['key_3']
    CRR['OBU_ANNUAL_INCOME'] = CRR['OBU_ANNUAL_INCOME'].fillna(0)
    CRR['SCORE'] = CRR['SCORE'] + CRR['OBU_ANNUAL_INCOME']*Dict['key_4']
    
    CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_5']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_6']
    CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_7']

    CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_8']
    CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_9']
    CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_10']
    CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_11']
    CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_12']
    CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_13']
    CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_14']
    CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_15']
    CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_16']
    CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_17']
    CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_18']
    CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_19']
    CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_20']
    CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_21']
    
    # 分數排序，取與真實 Y 相等數量之預測 Y
    CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
    CRR['PREDICT'] = 'N'
    CRR.loc[range(0,len(CRR[CRR['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'
    
    recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
    precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
    f1_score = 2*precision*recall/(precision+recall)
    
    outcome.append(f1_score)
    beta[i] = Dict.values()

# %%
plt.hist(outcome)
# Out:
# (array([  1.,   1.,   0.,   1.,   0.,   1.,   1.,   1., 145., 849.]),
#  array([0.16262567, 0.20224719, 0.24186872, 0.28149024, 0.32111177,
#         0.36073329, 0.40035482, 0.43997635, 0.47959787, 0.5192194 ,
#         0.55884092]),
#  <BarContainer object of 10 artists>)

# %%
max(outcome)
# Out:
# 0.5588409225310467

# %%
beta[outcome.index(max(outcome))]
# Out:
# dict_values([0.6746573677268254, 0.18429082396895569, 0.4809856248220816, 0.9089100400350772, 0.8802344871086134, 0.9281798824077446, 0.651927574882422, 0.3790791752497781, 0.5716675654780496, 0.14462950721310341, 0.02619508513259683, 0.4167435006299963, 0.6122812380923761, 0.9976388089899757, 0.5809615175747395, 0.5433732353210624, 0.5068059395972049, 0.978999384160833, 0.20348035104762452, 0.23365662946913557, 0.1945898063514121, 0.2597469433784432])

# %%
# Feed the best outcome into the model and check the quality of prediction for it
# 代入最佳結果
CRR = pd.read_csv('OBU_fakedata.csv')
CRR['SCORE'] = 0

values = beta[outcome.index(max(outcome))]
keys = ['key_' + str(i) for i in range(22)]
Dict = dict(zip(keys, values))

CRR.loc[CRR['CMFCUS1_FINANCIAL_ACT'] == 'Y', 'SCORE'] += Dict['key_0']
CRR.loc[CRR['EB_FG'] == 'v', 'SCORE'] += Dict['key_1']
CRR.loc[CRR['CDD_STATUS'] == 'N', 'SCORE'] += Dict['key_2']
CRR['AMT_RANGE'] = CRR['AMT_RANGE'].fillna(0)
CRR['SCORE'] = CRR['SCORE'] + CRR['AMT_RANGE']*Dict['key_3']
CRR['OBU_ANNUAL_INCOME'] = CRR['OBU_ANNUAL_INCOME'].fillna(0)
CRR['SCORE'] = CRR['SCORE'] + CRR['OBU_ANNUAL_INCOME']*Dict['key_4']
    
CRR['SCORE'] = CRR['SCORE'] + CRR['PEP_COUNT']*Dict['key_5']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_6']
CRR['SCORE'] = CRR['SCORE'] + CRR['REL_ADVRS_COUNT']*Dict['key_7']

CRR.loc[CRR['CUST_ADVRS'] == 'Y', 'SCORE'] += Dict['key_8']
CRR.loc[CRR['BEARER_SHARE'] == 'Y', 'SCORE'] += Dict['key_9']
CRR.loc[CRR['ISSUE_BEARER'] == 'Y', 'SCORE'] += Dict['key_10']
CRR.loc[CRR['JOB_RISK'] == 'H', 'SCORE'] += Dict['key_11']
CRR.loc[CRR['JOB_RISK'] == 'M', 'SCORE'] += Dict['key_12']
CRR.loc[CRR['JOB_RISK'] == 'L', 'SCORE'] += Dict['key_13']
CRR.loc[CRR['LN_FG'] == 'v', 'SCORE'] += Dict['key_14']
CRR.loc[CRR['IX_FG'] == 'v', 'SCORE'] += Dict['key_15']
CRR.loc[CRR['TR_FG'] == 'v', 'SCORE'] += Dict['key_16']
CRR.loc[CRR['TRUST_YN'] == 'v', 'SCORE'] += Dict['key_17']
CRR.loc[CRR['BD_FG'] == 'v', 'SCORE'] += Dict['key_18']
CRR.loc[CRR['DP_FG'] == 'v', 'SCORE'] += Dict['key_19']
CRR.loc[CRR['WM_FG'] == 'v', 'SCORE'] += Dict['key_20']
CRR.loc[CRR['CD_FG'] == 'v', 'SCORE'] += Dict['key_21']

CRR = CRR.sort_values(by='SCORE',ascending = False).reset_index(drop=True)
CRR['PREDICT'] = 'N'
CRR.loc[range(0,len(CRR[CRR['SAR_ALERT']=='Y'])),'PREDICT'] = 'Y'


recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
f1_score = 2*precision*recall/(precision+recall)
    
accuracy = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]) + len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')]))/len(CRR) 
recall = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['SAR_ALERT']=='Y'])
precision = (len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')]))/len(CRR[CRR['PREDICT']=='Y'])
f1_score = 2*precision*recall/(precision+recall)
TT_PT = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='Y')])
TT_PF = len(CRR[(CRR['SAR_ALERT']=='Y') & (CRR['PREDICT']=='N')])
TF_PF = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='N')])
TF_PT = len(CRR[(CRR['SAR_ALERT']=='N') & (CRR['PREDICT']=='Y')])

# %%
## F1 score 不同最佳結果，需要 Debug
print('Accuracy: ', accuracy, 'f1: ', f1_score, 'TT_PT: ', TT_PT, 'TT_PF: ', TT_PF, 'TF_PF: ', TF_PF, 'TF_PT: ', TF_PT)
# Out:
# Accuracy:  0.9860480207657365 f1:  0.6694263749260793 TT_PT:  1132 TT_PF:  559 TF_PF:  77882 TF_PT:  559

# %%
print(recall, precision)
# Out:
# 0.6694263749260793 0.6694263749260793
